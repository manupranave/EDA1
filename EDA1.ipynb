# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS ON A DATASET**

# %% [markdown]
# 1.	Data Cleaning and Preparation?

# %%
#●	Load the dataset into a DataFrame or equivalent data structure.
import pandas as pd
from pandas import*

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-ee1518a4-0e5b-48b0-9795-1db63b139999" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ee1518a4-0e5b-48b0-9795-1db63b139999">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
d_frame=read_csv('Cardiotocographic.csv')
d_frame
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
#●	Handle missing values appropriately (e.g., imputation, deletion).
d_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
d_frame.isnull()
# Out:
#          LB     AC     FM     UC     DL     DS     DP   ASTV   MSTV   ALTV  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2121  False  False  False  False  False  False  False  False  False  False
# 2122  False  False  False  False  False  False  False  False  False  False
# 2123  False  False  False  False  False  False  False  False  False  False
# 2124  False  False  False  False  False  False  False  False  False  False
# 2125  False  False  False  False  False  False  False  False  False  False
#
#        MLTV  Width  Tendency    NSP
# ...

# %%
d_frame.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
mean_lb=d_frame['LB'].mean()
d_frame['LB'].fillna(mean_lb,inplace=True)
d_frame['LB'].isnull().sum()
# Out:
# 0

# %%
mean_ac=d_frame['AC'].mean()
d_frame['AC'].fillna(mean_ac,inplace=True)
d_frame['AC'].isnull().sum()
# Out:
# 0

# %%
mean_ds=d_frame['DS'].mean()
d_frame['DS'].fillna(mean_ds,inplace=True)
d_frame['DS'].isnull().sum()
# Out:
# 0

# %%
mean_dp=d_frame['DP'].mean()
d_frame['DP'].fillna(mean_dp,inplace=True)
d_frame['DP'].isnull().sum()
# Out:
# 0

# %%
mean_mltv=d_frame['MLTV'].mean()
d_frame['MLTV'].fillna(mean_mltv,inplace=True)
d_frame['MLTV'].isnull().sum()
# Out:
# 0

# %%
mean_width=d_frame['Width'].mean()
d_frame['Width'].fillna(mean_width,inplace=True)
d_frame['Width'].isnull().sum()
# Out:
# 0

# %%
mean_tendency=d_frame['Tendency'].mean()
d_frame['Tendency'].fillna(mean_tendency,inplace=True)
d_frame['Tendency'].isnull().sum()
# Out:
# 0

# %%
mean_nsp=d_frame['NSP'].mean()
d_frame['NSP'].fillna(mean_nsp,inplace=True)
d_frame['NSP'].isnull().sum()
# Out:
# 0

# %%
d_frame.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
#●	Detect and treat outliers if necessary.
import numpy as np
from numpy import*
from scipy import stats
z_scores=abs(stats.zscore(d_frame))
outliers=(z_scores>3).any(axis=1)
df_no_outliers=d_frame[outliers]

# %%
d_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2126 non-null   float64
#  1   AC        2126 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2126 non-null   float64
#  6   DP        2126 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2126 non-null   float64
#  11  Width     2126 non-null   float64
#  12  Tendency  2126 non-null   float64
#  13  NSP       2126 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %% [markdown]
# 2.	Statistical Summary?

# %%
#●	Provide a statistical summary for each variable in the dataset, including measures of central tendency (mean, median) and dispersion (standard deviation, interquartile range).
print(df_no_outliers.describe())
# Out:
#                LB          AC          FM          UC          DL          DS  \
# count  257.000000  257.000000  257.000000  257.000000  257.000000  257.000000
# mean   133.610081    0.003402    0.051019    0.004388    0.003083    0.000020
# std     18.130675    0.007412    0.185992    0.005574    0.006142    0.000405
# min     51.842487   -0.019284   -0.480634   -0.014925   -0.015393   -0.001353
# 25%    128.000000    0.000000    0.000000    0.001406    0.000000    0.000000
# 50%    132.000000    0.000829    0.000000    0.004060    0.000760    0.000000
# 75%    139.000000    0.005068    0.007669    0.006180    0.004359    0.000000
# max    214.000000    0.038567    0.961268    0.030002    0.030769    0.002706
#
#                  DP        ASTV        MSTV        ALTV        MLTV  \
# count  2.570000e+02  257.000000  257.000000  257.000000  257.000000
# mean   7.079412e-04   47.905877    1.954931   18.227904    7.961530
# ...

# %%
print('Variables With High Standard Deviation :')
print(df_no_outliers.describe().loc['std'][df_no_outliers.describe().loc['std']>10])
print('\n')
print('Variables With High Skewness :')
print(df_no_outliers.skew()[df_no_outliers.skew()>1])
print('\n')
print('Variables With High Kurtosis :')
print(df_no_outliers.kurtosis()[df_no_outliers.kurtosis()>3])
# Out:
# Variables With High Standard Deviation :
# LB       18.130675
# ASTV     29.483929
# ALTV     40.691917
# MLTV     17.237158
# Width    68.475881
# Name: std, dtype: float64
#
#
# Variables With High Skewness :
# AC      2.348253
# FM      2.008815
# UC      1.664440
# DL      1.258929
# DS      2.832774
# DP      2.560020
# MSTV    2.412075
# ALTV    2.016864
# MLTV    2.549689
# dtype: float64
#
#
# Variables With High Kurtosis :
# LB          12.968009
# AC          11.110435
# FM           9.209672
# UC          10.100599
# DL           6.385087
# DS          25.116857
# DP          11.696641
# ASTV         5.790506
# MSTV        11.404925
# ALTV         5.759982
# MLTV        17.319193
# Width        6.412677
# Tendency     3.435064
# dtype: float64

# %% [markdown]
# 3.	Data Visualization?

# %%
#●	Create histograms or boxplots to visualize the distributions of various numerical variables.
import matplotlib.pyplot as plt
from matplotlib.pyplot import*

# %%
#boxplot
d_frame.boxplot(figsize=(10,6))
xlabel('Numerical Columns')
ylabel('Values')
show()

# %%
#histogram
d_frame.hist(figsize=(12,10),edgecolor='black')
show()

# %%
correlation=df_no_outliers.corr(numeric_only=True)
correlation
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.015448  0.043497 -0.177398 -0.106174 -0.010620
# AC       -0.015448  1.000000 -0.035353  0.054723 -0.095084 -0.057607
# FM        0.043497 -0.035353  1.000000 -0.052242 -0.033551  0.020124
# UC       -0.177398  0.054723 -0.052242  1.000000  0.051555 -0.012125
# DL       -0.106174 -0.095084 -0.033551  0.051555  1.000000  0.081937
# DS       -0.010620 -0.057607  0.020124 -0.012125  0.081937  1.000000
# DP       -0.002374 -0.080177  0.084222  0.010083  0.012369 -0.008095
# ASTV      0.070221 -0.138616 -0.058072 -0.133328 -0.007073  0.013754
# MSTV     -0.026772  0.032397 -0.067700  0.108175  0.246650  0.009551
# ALTV      0.066915 -0.107550 -0.054455 -0.146571 -0.127573 -0.016359
# MLTV      0.053747 -0.041419 -0.009022 -0.018365 -0.123218  0.045438
# Width    -0.063297  0.069334  0.085335  0.084610  0.203459  0.065486
# Tendency  0.089313  0.080087 -0.028208  0.009017 -0.202499 -0.025601
# ...

# %%
#●	Generate scatter plots or correlation heatmaps to explore relationships between pairs of variables.
import seaborn as sns
from seaborn import*

# %%
figure(figsize=(10,8))
heatmap(correlation,annot=True,cmap="coolwarm",vmin=-1,fmt='2f')
show()

# %%
#●	Employ advanced visualization techniques like pair plots, or violin plots for deeper insights.
pairplot(d_frame)
show()

# %% [markdown]
# 4.	Pattern Recognition and Insights?

# %%
#●	Identify any correlations between variables and discuss their potential implications.
corr_matrix=df_no_outliers.corr()
print('Correlation Matrix :',corr_matrix)
#highly correlated variables
highly_correlated_vars=[]
for i in range(len(corr_matrix.columns)):
  for j in range(i+1,len(corr_matrix.columns)):
    col1=corr_matrix.columns[i]
    col2=corr_matrix.columns[j]
    correlation=abs(corr_matrix.iloc[i,j])
    if correlation>0.6:
      highly_correlated_vars.append((col1,col2,correlation))
print('\n')
print('Highly Correlated Variables :')
if highly_correlated_vars:
  for var in highly_correlated_vars:
    print(f'{var[0]} And {var[1]} Are Highly Correlated With Correlation of {var[2]:2f}')
else:
    print('No Highly Correlated Variables Found')
# Out:
# Correlation Matrix :                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.015448  0.043497 -0.177398 -0.106174 -0.010620
# AC       -0.015448  1.000000 -0.035353  0.054723 -0.095084 -0.057607
# FM        0.043497 -0.035353  1.000000 -0.052242 -0.033551  0.020124
# UC       -0.177398  0.054723 -0.052242  1.000000  0.051555 -0.012125
# DL       -0.106174 -0.095084 -0.033551  0.051555  1.000000  0.081937
# DS       -0.010620 -0.057607  0.020124 -0.012125  0.081937  1.000000
# DP       -0.002374 -0.080177  0.084222  0.010083  0.012369 -0.008095
# ASTV      0.070221 -0.138616 -0.058072 -0.133328 -0.007073  0.013754
# MSTV     -0.026772  0.032397 -0.067700  0.108175  0.246650  0.009551
# ALTV      0.066915 -0.107550 -0.054455 -0.146571 -0.127573 -0.016359
# MLTV      0.053747 -0.041419 -0.009022 -0.018365 -0.123218  0.045438
# Width    -0.063297  0.069334  0.085335  0.084610  0.203459  0.065486
# ...

# %%
#●	Look for trends or patterns over time if temporal data is available.
if 'data' in df_no_outliers.columns or 'time' in df_no_outliers.columns:
  temporal_cols=['data' if 'data' in df_no_outliers.columns else 'time']
  for col in temporal_cols:
    figure(figsize=(10,6))
    plot(df_no_outliers[temporal_cols],df_no_outliers[col])
    title(f'Trend Of {col} Over Time')
    xlabel('Time')
    ylabel(col)
    show()
else:
  print('No Temporal Data Available For Trend Analysis.')
# Out:
# No Temporal Data Available For Trend Analysis.

# %% [markdown]
# 5.	Conclusion?

# %% [markdown]
# ●The dataset lacks temporal data,Which limits the analysis of trends over time.
#
# ●The variables exhibit varying levels of central tendency and dispersion,With some showing high standard deviation and skewness.
#
# ●Correlation analysis revealed no highly correlated variables,Suggesting that each variable contributes unique information.
#
# ●Visualisation techniques,Such as histograms,Boxplots,And scatter plots,Provided a deeper understanding of the distribution and relationships between variables.
#
# ●Variables with high standard deviation,Skewness,And kurtosis were identified,Which may require transformation or special handling in future analysis.
